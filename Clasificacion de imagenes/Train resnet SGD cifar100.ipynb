# %% [markdown]
# # Initial Setup

# %%
import os
import numpy as np
import datetime
import time
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.python.util.tf_export import keras_export

print(tf.__version__)
# Out:
# 2.2.0

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Imagenet Subset

# %%
dataDir = '/data/datasets/cifar100/raw'

configDir = 'config'
resultsDir = 'results'
modelsDir = 'saved_models/cifar100_resnet_SGD_v1'
logsDir = 'logs/cifar100_resnet_SGD_v1'

# %%
BATCH_SIZE = 64
NUM_EPOCHS = 100
LOG_STEPS = 100
AUTOTUNE = tf.data.experimental.AUTOTUNE

NUM_CLASSES = 100
IMG_HEIGHT = 32
IMG_WIDTH = 32
NUM_CHANNELS = 3

IMG_SIZE = (IMG_HEIGHT, IMG_WIDTH)

# %%
if not os.path.exists(configDir):
  os.makedirs(configDir)

if not os.path.exists(resultsDir):
  os.makedirs(resultsDir)

if not os.path.exists(modelsDir):
  os.makedirs(modelsDir)
        
if not os.path.exists(logsDir):
  os.makedirs(logsDir)

# %%
def unpickle(file):
  import pickle
  with open(file, 'rb') as fo:
    cifar_dict = pickle.load(fo, encoding='bytes')
  return cifar_dict

def show_batch(image_batch, label_batch):
  plt.figure(figsize=(10,10))
  for n in range(25):
    ax = plt.subplot(5,5,n+1)
    plt.imshow(image_batch[n])
    plt.title(CLASS_NAMES[label_batch[n]==1][0].title())
    plt.axis('off')

# %%
def rotate_zoom_tf(image, angle, zoom):

  angleRad = angle/180.*np.pi

  if image.shape.__len__() ==4:
    random_angles = tf.random.uniform(shape = (tf.shape(image)[0], ), minval = -angleRad, maxval = angleRad)
    random_zoom = tf.random.uniform(shape = (tf.shape(image)[0], ), minval = 1-zoom, maxval = 1+zoom)
  if image.shape.__len__() ==3:
    random_angles = tf.random.uniform(shape = (), minval = -angleRad, maxval = angleRad)
    random_zoom = tf.random.uniform(shape = (), minval = 1-zoom, maxval = 1+zoom)

  paddings = tf.constant([[int(IMG_HEIGHT/4), int(IMG_HEIGHT/4)], [int(IMG_WIDTH/4), int(IMG_WIDTH/4)], [0,0]])
  img = tf.pad(image, paddings, "SYMMETRIC")
  img = tfa.image.rotate(img, random_angles)
  img = tf.image.resize_with_crop_or_pad(img, int(IMG_HEIGHT*random_zoom), int(IMG_WIDTH*random_zoom))
  img = tf.image.resize(img, [IMG_HEIGHT,IMG_WIDTH], method=tf.image.ResizeMethod.BILINEAR)

  return img

def rotate_tf(image, angle):
  angleRad = angle/180.*np.pi

  if image.shape.__len__() ==4:   
    random_angles = tf.random.uniform(shape = (tf.shape(image)[0], ), minval = -angleRad, maxval = angleRad)
  if image.shape.__len__() ==3:
    random_angles = tf.random.uniform(shape = (), minval = -angleRad, maxval = angleRad)

  paddings = tf.constant([[int(IMG_HEIGHT/4), int(IMG_HEIGHT/4)], [int(IMG_WIDTH/4), int(IMG_WIDTH/4)], [0,0]])
  img = tf.pad(image, paddings, "SYMMETRIC")
  img = tfa.image.rotate(img, random_angles)
  img = tf.image.resize_with_crop_or_pad(img, IMG_HEIGHT, IMG_WIDTH)

  return img

def augment(image, label):
  #img = tf.image.rot90(image)
  img = tf.image.flip_left_right(image)
  #img = rotate_tf(image, 20)
  img = rotate_zoom_tf(image, 20, 0.2)
  #img = tf.image.random_brightness(img, 0.05)
  #img = tf.image.random_contrast(img, 0.9, 1.1)
  img = tf.clip_by_value(img, 0.0, 1.0)

  return (img, label)

def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
  # This is a small dataset, only load it once, and keep it in memory.
  # use `.cache(filename)` to cache preprocessing work for datasets that don't
  # fit in memory.
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()

  ds = ds.shuffle(buffer_size=shuffle_buffer_size)

  ds = ds.map(augment, num_parallel_calls=AUTOTUNE)

  # Repeat forever
  ds = ds.repeat()

  ds = ds.batch(BATCH_SIZE)

  # `prefetch` lets the dataset fetch batches in the background while the model
  # is training.
  ds = ds.prefetch(buffer_size=AUTOTUNE)

  return ds

def prepare_for_validation(ds, cache=True, shuffle_buffer_size=1000):
  # This is a small dataset, only load it once, and keep it in memory.
  # use `.cache(filename)` to cache preprocessing work for datasets that don't
  # fit in memory.
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()

  ds = ds.batch(BATCH_SIZE)

  # `prefetch` lets the dataset fetch batches in the background while the model
  # is training.
  ds = ds.prefetch(buffer_size=AUTOTUNE)

  return ds

# %%
meta = unpickle(os.path.join(dataDir, 'meta'))
train = unpickle(os.path.join(dataDir, 'train'))
test = unpickle(os.path.join(dataDir, 'test'))

# %%
classDF = pd.DataFrame(meta[b'fine_label_names'], columns = ['Classes'], dtype=str)
CLASS_NAMES = np.array(classDF['Classes'])

# %%
trainX = np.vstack(train[b"data"])
trainX = trainX.reshape(len(trainX), NUM_CHANNELS, IMG_HEIGHT, IMG_WIDTH).transpose(0,2,3,1).astype("float32")/255
trainY = np.array(train[b'fine_labels'])
trainY = tf.one_hot(trainY, NUM_CLASSES)

testX = np.vstack(test[b"data"])
testX = testX.reshape(len(testX), NUM_CHANNELS, IMG_HEIGHT, IMG_WIDTH).transpose(0,2,3,1).astype("float32")/255
testY = np.array(test[b'fine_labels'])#.reshape(-1,1)
testY = tf.one_hot(testY, NUM_CLASSES)

# %%
print("Train dataset numpy array")
print(trainX.shape)
print(trainY.shape)

print("\nValidation dataset numpy array")
print(testX.shape)
print(testY.shape)
# Out:
# Train dataset numpy array
# (50000, 32, 32, 3)
# (50000, 100)
#
# Validation dataset numpy array
# (10000, 32, 32, 3)
# (10000, 100)

# %%
TRAIN_EXAMPLES = trainX.shape[0]
VAL_EXAMPLES = testX.shape[0]

TRAIN_STEPS = TRAIN_EXAMPLES//BATCH_SIZE
VAL_STEPS = VAL_EXAMPLES//BATCH_SIZE

# %%
trainLabelDS = tf.data.Dataset.from_tensor_slices((trainX, trainY))
valLabelDS = tf.data.Dataset.from_tensor_slices((testX, testY))

# %%
trainDS = prepare_for_training(trainLabelDS)
valDS = prepare_for_validation(valLabelDS)

# %%
image_batch, label_batch = next(iter(trainDS))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ## Create model

# %%
from models.resnet import ResNet

modelDiagramFile = os.path.join(resultsDir, 'model_resnet50_cifar100.png')

model = ResNet.build(32, 32, NUM_CHANNELS, NUM_CLASSES, (9, 9, 9), (64, 64, 128, 256), reg=0.0005)

#keras.utils.plot_model(model, to_file=modelDiagramFile, show_shapes=True)
#model.summary()

# %% [markdown]
# ## Train model

# %%
from utils.optimization import warmupdecay_learner

learning_rate_fn = warmupdecay_learner(batch_size=BATCH_SIZE,
                                  epoch_size=TRAIN_EXAMPLES,
                                  init_lr=1e-2,
                                  warmup_epochs=10,
                                  boundaries=[60, 80, 100],
                                  multipliers=[1.0, 0.1, 0.01, 0.001])

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate_fn,
                                    momentum=0.9,
                                    nesterov= None)

# %%
loss_obj = tf.keras.losses.CategoricalCrossentropy(
          label_smoothing=0.1)

# %%
metrics=[tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
         tf.keras.metrics.TopKCategoricalAccuracy(k=5, name='top_5_accuracy')]

# %%
model.compile(optimizer=optimizer,
              loss=loss_obj,
              metrics=metrics)

# %%
# Hack to log learning rate in Tensorboard

class TensorBoard(tf.keras.callbacks.TensorBoard):
    def _collect_learning_rate(self, logs):
        logs = logs or {}
        lr_schedule = getattr(self.model.optimizer, "lr", None)
        if isinstance(lr_schedule, tf.keras.optimizers.schedules.LearningRateSchedule):
            logs["learning_rate"] = tf.keras.backend.get_value(
                lr_schedule(self.model.optimizer.iterations)
            )
        return logs

    def _log_metrics(self, logs, prefix, step):
        super()._log_metrics(self._collect_learning_rate(logs), prefix, step)

# %%
from utils.keras_utils import TimeHistory

logsCheckDir = os.path.join(logsDir, datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))

tb_callback = TensorBoard(log_dir=logsCheckDir, histogram_freq=1)

perf_callback = TimeHistory(BATCH_SIZE,
                            LOG_STEPS,
                            logdir=logsCheckDir+'/metrics')

callbacks = [tb_callback, perf_callback]

# %%
startTime = time.time()

model.fit(trainDS,
          epochs=NUM_EPOCHS,
          steps_per_epoch=TRAIN_STEPS,
          initial_epoch=0,
          callbacks=callbacks,
          validation_data=valDS,
          validation_steps=VAL_STEPS,
          validation_freq=1)

endTime = time.time()

elapsedTime = (endTime - startTime)/60.
print("\nTotal time for model training: {} minutes".format(elapsedTime))
# Out:
# Epoch 1/100
#   2/781 [..............................] - ETA: 4:39 - loss: 5.2873 - accuracy: 0.0000e+00 - top_5_accuracy: 0.0469WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.333950). Check your callbacks.
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.333950). Check your callbacks.
# 781/781 [==============================] - 45s 57ms/step - loss: 5.1366 - accuracy: 0.0232 - top_5_accuracy: 0.0834 - val_loss: 5.0132 - val_accuracy: 0.0325 - val_top_5_accuracy: 0.1276 - learning_rate: 0.0010
# Epoch 2/100
# 781/781 [==============================] - 42s 54ms/step - loss: 4.9182 - accuracy: 0.0492 - top_5_accuracy: 0.1728 - val_loss: 4.7907 - val_accuracy: 0.0677 - val_top_5_accuracy: 0.2275 - learning_rate: 0.0020
# Epoch 3/100
# 781/781 [==============================] - 42s 54ms/step - loss: 4.7002 - accuracy: 0.0840 - top_5_accuracy: 0.2589 - val_loss: 4.5759 - val_accuracy: 0.1027 - val_top_5_accuracy: 0.3065 - learning_rate: 0.0030
# Epoch 4/100
# 781/781 [==============================] - 42s 54ms/step - loss: 4.4949 - accuracy: 0.1157 - top_5_accuracy: 0.3322 - val_loss: 4.3766 - val_accuracy: 0.1330 - val_top_5_accuracy: 0.3749 - learning_rate: 0.0040
# Epoch 5/100
# 781/781 [==============================] - 42s 54ms/step - loss: 4.3296 - accuracy: 0.1431 - top_5_accuracy: 0.3868 - val_loss: 4.2212 - val_accuracy: 0.1676 - val_top_5_accuracy: 0.4272 - learning_rate: 0.0050
# Epoch 6/100
# 781/781 [==============================] - 42s 54ms/step - loss: 4.1829 - accuracy: 0.1753 - top_5_accuracy: 0.4370 - val_loss: 4.0756 - val_accuracy: 0.1992 - val_top_5_accuracy: 0.4750 - learning_rate: 0.0060
# Epoch 7/100
# 781/781 [==============================] - 42s 54ms/step - loss: 4.0414 - accuracy: 0.2046 - top_5_accuracy: 0.4863 - val_loss: 3.9186 - val_accuracy: 0.2334 - val_top_5_accuracy: 0.5304 - learning_rate: 0.0070
# Epoch 8/100
# 781/781 [==============================] - 42s 54ms/step - loss: 3.8939 - accuracy: 0.2379 - top_5_accuracy: 0.5349 - val_loss: 3.8190 - val_accuracy: 0.2509 - val_top_5_accuracy: 0.5570 - learning_rate: 0.0080
# Epoch 9/100
# 781/781 [==============================] - 42s 54ms/step - loss: 3.7596 - accuracy: 0.2651 - top_5_accuracy: 0.5711 - val_loss: 3.6260 - val_accuracy: 0.3006 - val_top_5_accuracy: 0.6115 - learning_rate: 0.0090
# Epoch 10/100
# 781/781 [==============================] - 42s 54ms/step - loss: 3.6290 - accuracy: 0.2988 - top_5_accuracy: 0.6115 - val_loss: 3.5620 - val_accuracy: 0.3139 - val_top_5_accuracy: 0.6235 - learning_rate: 0.0100
# Epoch 11/100
# 781/781 [==============================] - 42s 54ms/step - loss: 3.5057 - accuracy: 0.3272 - top_5_accuracy: 0.6439 - val_loss: 3.4156 - val_accuracy: 0.3489 - val_top_5_accuracy: 0.6692 - learning_rate: 0.0100
# Epoch 12/100
# 781/781 [==============================] - 42s 54ms/step - loss: 3.3885 - accuracy: 0.3549 - top_5_accuracy: 0.6788 - val_loss: 3.3285 - val_accuracy: 0.3756 - val_top_5_accuracy: 0.6912 - learning_rate: 0.0100
# Epoch 13/100
# 781/781 [==============================] - 42s 54ms/step - loss: 3.2865 - accuracy: 0.3843 - top_5_accuracy: 0.7025 - val_loss: 3.2885 - val_accuracy: 0.3807 - val_top_5_accuracy: 0.7031 - learning_rate: 0.0100
# Epoch 14/100
# 781/781 [==============================] - 42s 54ms/step - loss: 3.1933 - accuracy: 0.4086 - top_5_accuracy: 0.7285 - val_loss: 3.1621 - val_accuracy: 0.4103 - val_top_5_accuracy: 0.7350 - learning_rate: 0.0100
# Epoch 15/100
# 781/781 [==============================] - 42s 54ms/step - loss: 3.1145 - accuracy: 0.4261 - top_5_accuracy: 0.7464 - val_loss: 3.0845 - val_accuracy: 0.4342 - val_top_5_accuracy: 0.7531 - learning_rate: 0.0100
# Epoch 16/100
# 781/781 [==============================] - 42s 54ms/step - loss: 3.0407 - accuracy: 0.4494 - top_5_accuracy: 0.7640 - val_loss: 3.0522 - val_accuracy: 0.4417 - val_top_5_accuracy: 0.7548 - learning_rate: 0.0100
# Epoch 17/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.9799 - accuracy: 0.4638 - top_5_accuracy: 0.7774 - val_loss: 3.0158 - val_accuracy: 0.4565 - val_top_5_accuracy: 0.7676 - learning_rate: 0.0100
# Epoch 18/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.9138 - accuracy: 0.4790 - top_5_accuracy: 0.7936 - val_loss: 2.9632 - val_accuracy: 0.4628 - val_top_5_accuracy: 0.7796 - learning_rate: 0.0100
# Epoch 19/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.8602 - accuracy: 0.4954 - top_5_accuracy: 0.8026 - val_loss: 2.9025 - val_accuracy: 0.4828 - val_top_5_accuracy: 0.7958 - learning_rate: 0.0100
# Epoch 20/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.8068 - accuracy: 0.5114 - top_5_accuracy: 0.8154 - val_loss: 2.8748 - val_accuracy: 0.4897 - val_top_5_accuracy: 0.8005 - learning_rate: 0.0100
# Epoch 21/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.7650 - accuracy: 0.5215 - top_5_accuracy: 0.8249 - val_loss: 2.8622 - val_accuracy: 0.4936 - val_top_5_accuracy: 0.8011 - learning_rate: 0.0100
# Epoch 22/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.7209 - accuracy: 0.5352 - top_5_accuracy: 0.8324 - val_loss: 2.7366 - val_accuracy: 0.5281 - val_top_5_accuracy: 0.8272 - learning_rate: 0.0100
# Epoch 23/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.6859 - accuracy: 0.5421 - top_5_accuracy: 0.8396 - val_loss: 2.7727 - val_accuracy: 0.5175 - val_top_5_accuracy: 0.8184 - learning_rate: 0.0100
# Epoch 24/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.6542 - accuracy: 0.5507 - top_5_accuracy: 0.8449 - val_loss: 2.7153 - val_accuracy: 0.5346 - val_top_5_accuracy: 0.8311 - learning_rate: 0.0100
# Epoch 25/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.6094 - accuracy: 0.5656 - top_5_accuracy: 0.8532 - val_loss: 2.7273 - val_accuracy: 0.5311 - val_top_5_accuracy: 0.8265 - learning_rate: 0.0100
# Epoch 26/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.5829 - accuracy: 0.5737 - top_5_accuracy: 0.8590 - val_loss: 2.7003 - val_accuracy: 0.5368 - val_top_5_accuracy: 0.8282 - learning_rate: 0.0100
# Epoch 27/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.5539 - accuracy: 0.5824 - top_5_accuracy: 0.8628 - val_loss: 2.6436 - val_accuracy: 0.5541 - val_top_5_accuracy: 0.8428 - learning_rate: 0.0100
# Epoch 28/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.5215 - accuracy: 0.5896 - top_5_accuracy: 0.8697 - val_loss: 2.6717 - val_accuracy: 0.5505 - val_top_5_accuracy: 0.8350 - learning_rate: 0.0100
# Epoch 29/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.4908 - accuracy: 0.6019 - top_5_accuracy: 0.8758 - val_loss: 2.6400 - val_accuracy: 0.5603 - val_top_5_accuracy: 0.8357 - learning_rate: 0.0100
# Epoch 30/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.4730 - accuracy: 0.6041 - top_5_accuracy: 0.8774 - val_loss: 2.6378 - val_accuracy: 0.5601 - val_top_5_accuracy: 0.8424 - learning_rate: 0.0100
# Epoch 31/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.4506 - accuracy: 0.6091 - top_5_accuracy: 0.8816 - val_loss: 2.6359 - val_accuracy: 0.5566 - val_top_5_accuracy: 0.8396 - learning_rate: 0.0100
# Epoch 32/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.4287 - accuracy: 0.6186 - top_5_accuracy: 0.8832 - val_loss: 2.6617 - val_accuracy: 0.5531 - val_top_5_accuracy: 0.8426 - learning_rate: 0.0100
# Epoch 33/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.4045 - accuracy: 0.6240 - top_5_accuracy: 0.8905 - val_loss: 2.5781 - val_accuracy: 0.5792 - val_top_5_accuracy: 0.8561 - learning_rate: 0.0100
# Epoch 34/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.3853 - accuracy: 0.6304 - top_5_accuracy: 0.8916 - val_loss: 2.5841 - val_accuracy: 0.5784 - val_top_5_accuracy: 0.8504 - learning_rate: 0.0100
# Epoch 35/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.3646 - accuracy: 0.6362 - top_5_accuracy: 0.8952 - val_loss: 2.6304 - val_accuracy: 0.5630 - val_top_5_accuracy: 0.8389 - learning_rate: 0.0100
# Epoch 36/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.3467 - accuracy: 0.6417 - top_5_accuracy: 0.8988 - val_loss: 2.5797 - val_accuracy: 0.5717 - val_top_5_accuracy: 0.8542 - learning_rate: 0.0100
# Epoch 37/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.3323 - accuracy: 0.6448 - top_5_accuracy: 0.8999 - val_loss: 2.5990 - val_accuracy: 0.5692 - val_top_5_accuracy: 0.8442 - learning_rate: 0.0100
# Epoch 38/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.3096 - accuracy: 0.6536 - top_5_accuracy: 0.9038 - val_loss: 2.5799 - val_accuracy: 0.5746 - val_top_5_accuracy: 0.8492 - learning_rate: 0.0100
# Epoch 39/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.3037 - accuracy: 0.6534 - top_5_accuracy: 0.9038 - val_loss: 2.5415 - val_accuracy: 0.5918 - val_top_5_accuracy: 0.8568 - learning_rate: 0.0100
# Epoch 40/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.2841 - accuracy: 0.6590 - top_5_accuracy: 0.9080 - val_loss: 2.5206 - val_accuracy: 0.5933 - val_top_5_accuracy: 0.8582 - learning_rate: 0.0100
# Epoch 41/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.2722 - accuracy: 0.6629 - top_5_accuracy: 0.9113 - val_loss: 2.5400 - val_accuracy: 0.5922 - val_top_5_accuracy: 0.8575 - learning_rate: 0.0100
# Epoch 42/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.2589 - accuracy: 0.6666 - top_5_accuracy: 0.9131 - val_loss: 2.5100 - val_accuracy: 0.6014 - val_top_5_accuracy: 0.8620 - learning_rate: 0.0100
# Epoch 43/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.2370 - accuracy: 0.6766 - top_5_accuracy: 0.9156 - val_loss: 2.5170 - val_accuracy: 0.5960 - val_top_5_accuracy: 0.8640 - learning_rate: 0.0100
# Epoch 44/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.2394 - accuracy: 0.6735 - top_5_accuracy: 0.9162 - val_loss: 2.5194 - val_accuracy: 0.5968 - val_top_5_accuracy: 0.8603 - learning_rate: 0.0100
# Epoch 45/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.2150 - accuracy: 0.6830 - top_5_accuracy: 0.9197 - val_loss: 2.5590 - val_accuracy: 0.5849 - val_top_5_accuracy: 0.8572 - learning_rate: 0.0100
# Epoch 46/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.2142 - accuracy: 0.6801 - top_5_accuracy: 0.9206 - val_loss: 2.5527 - val_accuracy: 0.5901 - val_top_5_accuracy: 0.8550 - learning_rate: 0.0100
# Epoch 47/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.1990 - accuracy: 0.6871 - top_5_accuracy: 0.9222 - val_loss: 2.5106 - val_accuracy: 0.6042 - val_top_5_accuracy: 0.8616 - learning_rate: 0.0100
# Epoch 48/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.1815 - accuracy: 0.6935 - top_5_accuracy: 0.9256 - val_loss: 2.5861 - val_accuracy: 0.5805 - val_top_5_accuracy: 0.8508 - learning_rate: 0.0100
# Epoch 49/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.1786 - accuracy: 0.6935 - top_5_accuracy: 0.9250 - val_loss: 2.5577 - val_accuracy: 0.5883 - val_top_5_accuracy: 0.8540 - learning_rate: 0.0100
# Epoch 50/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.1718 - accuracy: 0.6960 - top_5_accuracy: 0.9257 - val_loss: 2.5258 - val_accuracy: 0.5967 - val_top_5_accuracy: 0.8581 - learning_rate: 0.0100
# Epoch 51/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.1563 - accuracy: 0.7006 - top_5_accuracy: 0.9300 - val_loss: 2.4743 - val_accuracy: 0.6117 - val_top_5_accuracy: 0.8672 - learning_rate: 0.0100
# Epoch 52/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.1470 - accuracy: 0.7046 - top_5_accuracy: 0.9307 - val_loss: 2.5006 - val_accuracy: 0.6009 - val_top_5_accuracy: 0.8618 - learning_rate: 0.0100
# Epoch 53/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.1410 - accuracy: 0.7062 - top_5_accuracy: 0.9325 - val_loss: 2.4957 - val_accuracy: 0.6063 - val_top_5_accuracy: 0.8668 - learning_rate: 0.0100
# Epoch 54/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.1369 - accuracy: 0.7076 - top_5_accuracy: 0.9324 - val_loss: 2.4957 - val_accuracy: 0.6040 - val_top_5_accuracy: 0.8651 - learning_rate: 0.0100
# Epoch 55/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.1331 - accuracy: 0.7106 - top_5_accuracy: 0.9339 - val_loss: 2.5341 - val_accuracy: 0.5954 - val_top_5_accuracy: 0.8595 - learning_rate: 0.0100
# Epoch 56/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.1236 - accuracy: 0.7125 - top_5_accuracy: 0.9358 - val_loss: 2.5261 - val_accuracy: 0.6002 - val_top_5_accuracy: 0.8615 - learning_rate: 0.0100
# Epoch 57/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.1137 - accuracy: 0.7166 - top_5_accuracy: 0.9373 - val_loss: 2.4860 - val_accuracy: 0.6130 - val_top_5_accuracy: 0.8662 - learning_rate: 0.0100
# Epoch 58/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.1036 - accuracy: 0.7200 - top_5_accuracy: 0.9386 - val_loss: 2.5128 - val_accuracy: 0.6041 - val_top_5_accuracy: 0.8669 - learning_rate: 0.0100
# Epoch 59/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.0929 - accuracy: 0.7222 - top_5_accuracy: 0.9381 - val_loss: 2.5011 - val_accuracy: 0.6088 - val_top_5_accuracy: 0.8614 - learning_rate: 0.0100
# Epoch 60/100
# 781/781 [==============================] - 42s 54ms/step - loss: 2.0871 - accuracy: 0.7249 - top_5_accuracy: 0.9395 - val_loss: 2.5352 - val_accuracy: 0.6019 - val_top_5_accuracy: 0.8600 - learning_rate: 0.0100
# Epoch 61/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.9120 - accuracy: 0.7895 - top_5_accuracy: 0.9617 - val_loss: 2.3031 - val_accuracy: 0.6651 - val_top_5_accuracy: 0.8934 - learning_rate: 0.0010
# Epoch 62/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.8309 - accuracy: 0.8194 - top_5_accuracy: 0.9688 - val_loss: 2.2955 - val_accuracy: 0.6632 - val_top_5_accuracy: 0.8925 - learning_rate: 0.0010
# Epoch 63/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.8052 - accuracy: 0.8292 - top_5_accuracy: 0.9719 - val_loss: 2.2838 - val_accuracy: 0.6698 - val_top_5_accuracy: 0.8925 - learning_rate: 0.0010
# Epoch 64/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.7854 - accuracy: 0.8347 - top_5_accuracy: 0.9743 - val_loss: 2.2877 - val_accuracy: 0.6666 - val_top_5_accuracy: 0.8945 - learning_rate: 0.0010
# Epoch 65/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.7720 - accuracy: 0.8409 - top_5_accuracy: 0.9759 - val_loss: 2.2819 - val_accuracy: 0.6691 - val_top_5_accuracy: 0.8937 - learning_rate: 0.0010
# Epoch 66/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.7615 - accuracy: 0.8449 - top_5_accuracy: 0.9753 - val_loss: 2.2889 - val_accuracy: 0.6663 - val_top_5_accuracy: 0.8928 - learning_rate: 0.0010
# Epoch 67/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.7481 - accuracy: 0.8468 - top_5_accuracy: 0.9778 - val_loss: 2.2943 - val_accuracy: 0.6621 - val_top_5_accuracy: 0.8906 - learning_rate: 0.0010
# Epoch 68/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.7437 - accuracy: 0.8492 - top_5_accuracy: 0.9785 - val_loss: 2.2789 - val_accuracy: 0.6708 - val_top_5_accuracy: 0.8927 - learning_rate: 0.0010
# Epoch 69/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.7331 - accuracy: 0.8528 - top_5_accuracy: 0.9786 - val_loss: 2.2873 - val_accuracy: 0.6718 - val_top_5_accuracy: 0.8941 - learning_rate: 0.0010
# Epoch 70/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.7219 - accuracy: 0.8560 - top_5_accuracy: 0.9802 - val_loss: 2.2913 - val_accuracy: 0.6659 - val_top_5_accuracy: 0.8936 - learning_rate: 0.0010
# Epoch 71/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.7176 - accuracy: 0.8580 - top_5_accuracy: 0.9805 - val_loss: 2.2883 - val_accuracy: 0.6684 - val_top_5_accuracy: 0.8920 - learning_rate: 0.0010
# Epoch 72/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.7086 - accuracy: 0.8598 - top_5_accuracy: 0.9810 - val_loss: 2.2872 - val_accuracy: 0.6678 - val_top_5_accuracy: 0.8921 - learning_rate: 0.0010
# Epoch 73/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.7023 - accuracy: 0.8610 - top_5_accuracy: 0.9811 - val_loss: 2.2914 - val_accuracy: 0.6698 - val_top_5_accuracy: 0.8914 - learning_rate: 0.0010
# Epoch 74/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6971 - accuracy: 0.8633 - top_5_accuracy: 0.9816 - val_loss: 2.2880 - val_accuracy: 0.6705 - val_top_5_accuracy: 0.8899 - learning_rate: 0.0010
# Epoch 75/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6895 - accuracy: 0.8642 - top_5_accuracy: 0.9821 - val_loss: 2.2897 - val_accuracy: 0.6668 - val_top_5_accuracy: 0.8892 - learning_rate: 0.0010
# Epoch 76/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6831 - accuracy: 0.8680 - top_5_accuracy: 0.9833 - val_loss: 2.2895 - val_accuracy: 0.6689 - val_top_5_accuracy: 0.8884 - learning_rate: 0.0010
# Epoch 77/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6795 - accuracy: 0.8680 - top_5_accuracy: 0.9835 - val_loss: 2.2911 - val_accuracy: 0.6661 - val_top_5_accuracy: 0.8908 - learning_rate: 0.0010
# Epoch 78/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6723 - accuracy: 0.8707 - top_5_accuracy: 0.9840 - val_loss: 2.2933 - val_accuracy: 0.6653 - val_top_5_accuracy: 0.8897 - learning_rate: 0.0010
# Epoch 79/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6666 - accuracy: 0.8725 - top_5_accuracy: 0.9834 - val_loss: 2.2908 - val_accuracy: 0.6708 - val_top_5_accuracy: 0.8886 - learning_rate: 0.0010
# Epoch 80/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6593 - accuracy: 0.8752 - top_5_accuracy: 0.9841 - val_loss: 2.2897 - val_accuracy: 0.6678 - val_top_5_accuracy: 0.8890 - learning_rate: 0.0010
# Epoch 81/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6432 - accuracy: 0.8805 - top_5_accuracy: 0.9862 - val_loss: 2.2739 - val_accuracy: 0.6720 - val_top_5_accuracy: 0.8921 - learning_rate: 1.0000e-04
# Epoch 82/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6362 - accuracy: 0.8822 - top_5_accuracy: 0.9862 - val_loss: 2.2794 - val_accuracy: 0.6704 - val_top_5_accuracy: 0.8901 - learning_rate: 1.0000e-04
# Epoch 83/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6361 - accuracy: 0.8825 - top_5_accuracy: 0.9862 - val_loss: 2.2725 - val_accuracy: 0.6699 - val_top_5_accuracy: 0.8925 - learning_rate: 1.0000e-04
# Epoch 84/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6326 - accuracy: 0.8836 - top_5_accuracy: 0.9870 - val_loss: 2.2787 - val_accuracy: 0.6705 - val_top_5_accuracy: 0.8900 - learning_rate: 1.0000e-04
# Epoch 85/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6311 - accuracy: 0.8846 - top_5_accuracy: 0.9873 - val_loss: 2.2729 - val_accuracy: 0.6708 - val_top_5_accuracy: 0.8924 - learning_rate: 1.0000e-04
# Epoch 86/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6339 - accuracy: 0.8846 - top_5_accuracy: 0.9856 - val_loss: 2.2771 - val_accuracy: 0.6703 - val_top_5_accuracy: 0.8909 - learning_rate: 1.0000e-04
# Epoch 87/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6291 - accuracy: 0.8864 - top_5_accuracy: 0.9864 - val_loss: 2.2717 - val_accuracy: 0.6722 - val_top_5_accuracy: 0.8928 - learning_rate: 1.0000e-04
# Epoch 88/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6285 - accuracy: 0.8862 - top_5_accuracy: 0.9868 - val_loss: 2.2712 - val_accuracy: 0.6731 - val_top_5_accuracy: 0.8921 - learning_rate: 1.0000e-04
# Epoch 89/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6298 - accuracy: 0.8848 - top_5_accuracy: 0.9868 - val_loss: 2.2747 - val_accuracy: 0.6707 - val_top_5_accuracy: 0.8926 - learning_rate: 1.0000e-04
# Epoch 90/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6256 - accuracy: 0.8868 - top_5_accuracy: 0.9871 - val_loss: 2.2724 - val_accuracy: 0.6715 - val_top_5_accuracy: 0.8928 - learning_rate: 1.0000e-04
# Epoch 91/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6264 - accuracy: 0.8871 - top_5_accuracy: 0.9867 - val_loss: 2.2733 - val_accuracy: 0.6712 - val_top_5_accuracy: 0.8925 - learning_rate: 1.0000e-04
# Epoch 92/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6223 - accuracy: 0.8877 - top_5_accuracy: 0.9870 - val_loss: 2.2767 - val_accuracy: 0.6708 - val_top_5_accuracy: 0.8912 - learning_rate: 1.0000e-04
# Epoch 93/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6239 - accuracy: 0.8876 - top_5_accuracy: 0.9875 - val_loss: 2.2801 - val_accuracy: 0.6691 - val_top_5_accuracy: 0.8925 - learning_rate: 1.0000e-04
# Epoch 94/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6241 - accuracy: 0.8893 - top_5_accuracy: 0.9871 - val_loss: 2.2826 - val_accuracy: 0.6678 - val_top_5_accuracy: 0.8906 - learning_rate: 1.0000e-04
# Epoch 95/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6244 - accuracy: 0.8878 - top_5_accuracy: 0.9864 - val_loss: 2.2795 - val_accuracy: 0.6684 - val_top_5_accuracy: 0.8926 - learning_rate: 1.0000e-04
# Epoch 96/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6191 - accuracy: 0.8901 - top_5_accuracy: 0.9870 - val_loss: 2.2823 - val_accuracy: 0.6690 - val_top_5_accuracy: 0.8907 - learning_rate: 1.0000e-04
# Epoch 97/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6197 - accuracy: 0.8886 - top_5_accuracy: 0.9881 - val_loss: 2.2809 - val_accuracy: 0.6697 - val_top_5_accuracy: 0.8905 - learning_rate: 1.0000e-04
# Epoch 98/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6194 - accuracy: 0.8888 - top_5_accuracy: 0.9878 - val_loss: 2.2802 - val_accuracy: 0.6702 - val_top_5_accuracy: 0.8907 - learning_rate: 1.0000e-04
# Epoch 99/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6217 - accuracy: 0.8869 - top_5_accuracy: 0.9864 - val_loss: 2.2773 - val_accuracy: 0.6707 - val_top_5_accuracy: 0.8927 - learning_rate: 1.0000e-04
# Epoch 100/100
# 781/781 [==============================] - 42s 54ms/step - loss: 1.6161 - accuracy: 0.8905 - top_5_accuracy: 0.9879 - val_loss: 2.2793 - val_accuracy: 0.6695 - val_top_5_accuracy: 0.8909 - learning_rate: 1.0000e-04
#
# Total time for model training: 70.4643339117368 minutes

# %% [markdown]
# ## Save model

# %%
modelFile = os.path.join(modelsDir, 'model_densenet169.h5')

model.save(modelFile)

# %% [markdown]
# ## Plot confusion matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

#     print(cm)

    fig, ax = plt.subplots(figsize=(16,16))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    '''
    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    '''
    fig.tight_layout()
    return ax


np.set_printoptions(precision=2)

# %%
y_pred=np.argmax(model.predict(testX), axis=1)
y_true=np.argmax(testY, axis=1)

#Compute the confusion matrix
confusion_mtx=confusion_matrix(y_true,y_pred)

# %%
# Plot non-normalized confusion matrix
plot_confusion_matrix(y_true, y_pred, classes=CLASS_NAMES,
                      title='Confusion matrix, without normalization')
